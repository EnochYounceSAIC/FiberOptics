# %% [markdown]
# <a href="https://colab.research.google.com/github/EnochYounceSAIC/FiberOptics/blob/main/weektwo/Left_to_Right_EDFA_attenuation_both_fixed.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This notebook covers the attenuation and EDFA noise. The first section assumes fixed gain while the second section is fixed power

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp

# %%
length = 3000
span = 100
#Fiber type: SMF-28
#current task: model EDFA noise and amplification
EDFA_noise = 4.7 #dB
EDFA_gain = 17 #dB
#fiber data sheet used : https://www.corning.com/media/worldwide/coc/documents/Fiber/product-information-sheets/PI-1470-AEN.pdf
#EDFA used EDFA 100s : https://www.thorlabs.com/newgrouppage9.cfm?objectgroup_ID=10680
#single wavelength light, using 1550nm
lambda_light = 1550e-9
f_light = 3e8/lambda_light
#using max attenuation as a graph or standard deviation is not provided
attenuation = 0.17 #dB/km
power_initial = 15-10*np.log10(70) #dBm
OSNR_initial = 33.5 #dB

# %%
distance = np.arange(0,length+1,1) #+1 to put an amplifier at the endpoint as would be done to read the signal
# Calculate power in mW
# Power starts at initial power, attenuates, and gets a discrete gain at each amplifier location starting from 100 km
power_mW = np.zeros(length+1)
power_mW[0] = 10**(power_initial/10) # Initial power in mW

for i in range(1, length+1):
    # Power at current point is power at previous point minus attenuation over 1 km
    power_mW[i] = power_mW[i-1] * 10**(-attenuation / 10)
    # Add EDFA gain at amplifier locations (at span, 2*span, 3*span, etc.)
    if i > 0 and i % span == 0:
        power_mW[i] *= 10**(EDFA_gain/10)


# Convert power back to dBm for potential uses later
power_dBm = 10 * np.log10(power_mW)

plt.plot(distance,power_dBm)
plt.xlabel('distance (km)')
plt.ylabel('power (dBm)')
plt.title('Power vs Distance of SMF-28 fiber with 1550 nm light with EDFA amplification')
plt.show()

# %%
#noise calculations
planks_const = 6.626e-34 #J*s
bandwidth_nm = 0.1e-9 #0.1nm
# Convert bandwidth from nm to frequency (Hz)
bandwidth_freq = bandwidth_nm * (f_light / lambda_light)

# Convert EDFA noise figure from dB to linear
EDFA_noise_linear = 10**(EDFA_noise/10)
power_ase_per_amp = planks_const * f_light * EDFA_noise_linear * (10**(EDFA_gain/10) - 1) * bandwidth_freq # J/s or Watts (W)

# Convert power_ase_per_amp from Watts to mW
power_ase_per_amp_mW = power_ase_per_amp * 1000

#graph
ASE_noise = np.zeros(length+1)
for i in range(100,length+1):
  ASE_noise[i] = ASE_noise[i-1]*1/(10**(attenuation/10))
  if(i%100 ==0):
      ASE_noise[i] *= 10**(EDFA_gain/10)
      ASE_noise[i] += power_ase_per_amp_mW



plt.plot(distance,ASE_noise)
plt.xlabel('distance (km)')
plt.ylabel('power (mW)')
plt.title("power of ASE noise versus distance")
plt.show()

# %%
# Add a small epsilon to noise to avoid division by zero and log of zero/negative
noise_plus_epsilon = ASE_noise + np.finfo(float).eps

# Calculate OSNR from accumulated noise
OSNR_calculated = 10*np.log10(power_mW/noise_plus_epsilon)
OSNR_initial_linear = 10**(OSNR_initial/10)
OSNR_calculated_linear = 10**(OSNR_calculated/10)
OSNR_total_linear = 1 / (1/OSNR_initial_linear + 1/OSNR_calculated_linear)

# Convert total SNR back to dB
OSNR_total = 10*np.log10(OSNR_total_linear)

plt.plot(distance,OSNR_total)
plt.xlabel('distance (km)')
plt.ylabel('OSNR (dB)')

plt.ylim(0,40)
plt.title('OSNR vs Distance of SMF-28 fiber with 1550 nm light')
plt.grid()
plt.show()
print(OSNR_total[2998])
# Out:
# 18.139313949385112

# %%
# Plot power_mW and noise_plus_epsilon on the same graph
fig, ax1 = plt.subplots()

ax1.plot(distance, power_mW, label='Signal Power (mW)', color='blue')
ax1.set_xlabel('distance (km)')
ax1.set_ylabel('Signal Power (mW)', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')
ax1.set_title('Signal Power and Noise vs Distance')
ax1.grid(True)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
ax2.plot(distance, noise_plus_epsilon, label='Accumulated Noise (mW)', color='red')
ax2.set_ylabel('Accumulated Noise (mW)', color='red')
ax2.tick_params(axis='y', labelcolor='red')

# Add legends
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc='upper left')
plt.xlim(1600,2000)
plt.show()

# %%
full_output = power_mW + ASE_noise
plt.plot(distance,full_output)
plt.xlabel('distance (km)')
plt.ylabel('power (mW)')
plt.title('Power vs Distance of SMF-28 fiber with 1550 nm light with EDFA amplification and noise Fixed gain')
plt.show()

# %% [markdown]
# Fixed power

# %%
total_signal = np.zeros(length+1)
total_signal[0] = 10**(power_initial/10)
total_ASE=np.zeros(length+1)
total_signal_power=np.zeros(length+1)
total_signal_power[0] = 10**(power_initial/10)
for i in range(1,length+1):
  # Attenuation
  total_signal[i] = total_signal[i-1] * 10**(-attenuation/10)
  total_ASE[i] = total_ASE[i-1] * 10**(-attenuation/10)
  total_signal_power[i] = total_signal_power[i-1] * 10**(-attenuation/10)


  if(i%span == 0):
    # Add ASE noise at amplifier
    total_ASE[i] += power_ase_per_amp_mW
    # Scale signal and noise to maintain fixed output power
    scaling_factor = total_signal[0] / (total_signal_power[i] + total_ASE[i])
    total_ASE[i] *= scaling_factor
    total_signal_power[i] *= scaling_factor
    total_signal[i] = total_ASE[i] + total_signal_power[i]


plt.plot(distance,total_signal)
plt.xlabel('distance (km)')
plt.ylabel('power (mW)')
plt.title('Power vs Distance of SMF-28 fiber with 1550 nm light with EDFA amplification and noise')
plt.show()

# %%
# Add a small epsilon to noise to avoid division by zero and log of zero/negative
noise_plus_epsilon = ASE_noise + np.finfo(float).eps

# Calculate OSNR from accumulated noise
OSNR_calculated = 10*np.log10(total_signal_power/noise_plus_epsilon)
OSNR_initial_linear = 10**(OSNR_initial/10)
OSNR_calculated_linear = 10**(OSNR_calculated/10)
OSNR_total_linear = 1 / (1/OSNR_initial_linear + 1/OSNR_calculated_linear)

# Convert total SNR back to dB
OSNR_total = 10*np.log10(OSNR_total_linear)

plt.plot(distance,OSNR_total)
plt.xlabel('distance (km)')
plt.ylabel('OSNR (dB)')

plt.ylim(0,40)
plt.title('OSNR vs Distance of SMF-28 fiber with 1550 nm light')
plt.grid()
plt.show()
print(OSNR_total[2998])
# Out:
# 15.003222917125587

# %% [markdown]
# BER from OSNR

# %%
#BER calculations pulled from : https://www.exfo.com/contentassets/c3a3f92426864ffba6330f549ae75f11/exfo_anote098_resolution-bandwidth-optical-rejection-ratio_en.pdf
#likely incorrect but I included it anyways
import scipy.integrate as sp_integrate
import numpy as np

BER = np.zeros(len(OSNR_total))
for i in range(len(OSNR_total)):
    BER[i] = (1/(np.sqrt(2*np.pi))) * sp_integrate.quad(lambda t: np.exp((-t**2)/2), OSNR[i], np.inf)[0]

plt.plot(distance,BER)
plt.xlabel('distance (km)')
plt.ylabel('BER')
plt.title('BER vs Distance of SMF-28 fiber with 1550 nm light Fixed Power')
plt.show()
